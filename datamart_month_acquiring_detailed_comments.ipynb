# %% [markdown]
# # Версия с подробными комментариями
#
# Это отдельная учебная копия тетрадки. Перед каждой code-ячейкой добавлен подробный разбор почти каждой строки, чтобы можно было объяснить логику любому коллеге.

# %% [markdown]
# # Витрина эквайринга по атрибутам MVP первой волны
#
# Зачем нужна тетрадка:
# - коллега задает месяц и запускает ячейки сверху вниз;
# - на выходе получает готовую витрину в CSV для дашборда.
#
# Ниже — расшифровка полей витрины на русском.

# %% [markdown]
# ### Подробный разбор кода (ячейка 1)
#
# - Строка 1: `import pandas as pd` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 3: `attributes_dict_df = pd.DataFrame([` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 4: `    {'attribute': 'report_month', 'description_ru': 'Отчетный месяц витрины (первый день месяца)'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 5: `    {'attribute': 'inn', 'description_ru': 'ИНН клиента'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 6: `    {'attribute': 'company_name', 'description_ru': 'Наименование клиента'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 7: `    {'attribute': 'agr_id', 'description_ru': 'ID договора из Alpha (если есть)'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 8: `    {'attribute': 'n_agr', 'description_ru': 'Внутренний номер договора в Alpha'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 9: `    {'attribute': 'contract_number', 'description_ru': 'Номер договора в Alpha'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 10: `    {'attribute': 'd_valid_from', 'description_ru': 'Дата начала действия договора'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 11: `    {'attribute': 'd_valid_to', 'description_ru': 'Дата окончания действия договора'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 12: `    {'attribute': 'cdi_id', 'description_ru': 'Идентификатор клиента в CDI'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 13: `    {'attribute': 'ssp_ocrm', 'description_ru': 'Сегмент/блок ОКРМ'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 14: `    {'attribute': 'ogrn', 'description_ru': 'ОГРН клиента'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 15: `    {'attribute': 'filial_rf', 'description_ru': 'Филиал РФ'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 16: `    {'attribute': 'vsp_name', 'description_ru': 'Наименование ВСП'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 17: `    {'attribute': 'vsp_code', 'description_ru': 'Код ВСП'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 18: `    {'attribute': 'tariff_name', 'description_ru': 'Тарифный план'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 19: `    {'attribute': 'retl_cnt', 'description_ru': 'Количество торговых точек'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 20: `    {'attribute': 'term_cnt', 'description_ru': 'Количество терминалов'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 21: `    {'attribute': 'trx_cnt', 'description_ru': 'Количество операций за месяц'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 22: `    {'attribute': 'trx_sum', 'description_ru': 'Сумма операций за месяц'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 23: `    {'attribute': 'commission_from_ops', 'description_ru': 'Комиссия с операций'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 24: `    {'attribute': 'commission_monthly', 'description_ru': 'Фиксированная комиссия в месяц'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 25: `    {'attribute': 'int_component', 'description_ru': 'Interchange / внутренняя составляющая'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 26: `    {'attribute': 'commission_total', 'description_ru': 'Итоговая комиссия'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 27: `    {'attribute': 'aur', 'description_ru': 'АУР (расчет по терминалам)'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 28: `    {'attribute': 'amortization', 'description_ru': 'Амортизация'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 29: `    {'attribute': 'chod', 'description_ru': 'ЧОД'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 30: `    {'attribute': 'fin_result', 'description_ru': 'Финансовый результат'},` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 31: `])` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 33: `attributes_dict_df` — Выполняет очередной технический шаг обработки в рамках pipeline.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
import pandas as pd

attributes_dict_df = pd.DataFrame([
    {'attribute': 'report_month', 'description_ru': 'Отчетный месяц витрины (первый день месяца)'},
    {'attribute': 'inn', 'description_ru': 'ИНН клиента'},
    {'attribute': 'company_name', 'description_ru': 'Наименование клиента'},
    {'attribute': 'agr_id', 'description_ru': 'ID договора из Alpha (если есть)'},
    {'attribute': 'n_agr', 'description_ru': 'Внутренний номер договора в Alpha'},
    {'attribute': 'contract_number', 'description_ru': 'Номер договора в Alpha'},
    {'attribute': 'd_valid_from', 'description_ru': 'Дата начала действия договора'},
    {'attribute': 'd_valid_to', 'description_ru': 'Дата окончания действия договора'},
    {'attribute': 'cdi_id', 'description_ru': 'Идентификатор клиента в CDI'},
    {'attribute': 'ssp_ocrm', 'description_ru': 'Сегмент/блок ОКРМ'},
    {'attribute': 'ogrn', 'description_ru': 'ОГРН клиента'},
    {'attribute': 'filial_rf', 'description_ru': 'Филиал РФ'},
    {'attribute': 'vsp_name', 'description_ru': 'Наименование ВСП'},
    {'attribute': 'vsp_code', 'description_ru': 'Код ВСП'},
    {'attribute': 'tariff_name', 'description_ru': 'Тарифный план'},
    {'attribute': 'retl_cnt', 'description_ru': 'Количество торговых точек'},
    {'attribute': 'term_cnt', 'description_ru': 'Количество терминалов'},
    {'attribute': 'trx_cnt', 'description_ru': 'Количество операций за месяц'},
    {'attribute': 'trx_sum', 'description_ru': 'Сумма операций за месяц'},
    {'attribute': 'commission_from_ops', 'description_ru': 'Комиссия с операций'},
    {'attribute': 'commission_monthly', 'description_ru': 'Фиксированная комиссия в месяц'},
    {'attribute': 'int_component', 'description_ru': 'Interchange / внутренняя составляющая'},
    {'attribute': 'commission_total', 'description_ru': 'Итоговая комиссия'},
    {'attribute': 'aur', 'description_ru': 'АУР (расчет по терминалам)'},
    {'attribute': 'amortization', 'description_ru': 'Амортизация'},
    {'attribute': 'chod', 'description_ru': 'ЧОД'},
    {'attribute': 'fin_result', 'description_ru': 'Финансовый результат'},
])

attributes_dict_df

# %% [markdown]
# ## 1) Загрузка библиотек
#
# Подключаем только необходимые библиотеки для расчета и выгрузки.

# %% [markdown]
# ### Подробный разбор кода (ячейка 2)
#
# - Строка 1: `import re` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 2: `from decimal import Decimal, InvalidOperation` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 3: `from pathlib import Path` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 5: `import pandas as pd` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 6: `from rail_connectors.connection import connect` — Импортирует библиотеку/модуль для работы текущей тетрадки.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
import re
from decimal import Decimal, InvalidOperation
from pathlib import Path

import pandas as pd
from rail_connectors.connection import connect

# %% [markdown]
# ## 2) Подключение к Impala
#
# Создаем подключение к хранилищу для SQL-запросов.

# %% [markdown]
# ### Подробный разбор кода (ячейка 3)
#
# - Строка 1: `imp = connect(` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 2: `    to='IMPALA',` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 3: `    extra_options={'db': 'sandbox_ai'},` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 4: `    driver_args={'tez.queue.name': 'ai'},` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 5: `    kerberos={` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 6: `        'keytab_path': '/home/jovyan/test_requests/tech.keytab',` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 7: `        'use_credentials': True,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 8: `        'update_keytab': True,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 9: `    },` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 10: `    user_params={'user_name': 'Shestopalov-VYur'}` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 11: `)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 12: `imp._init_connection()` — Выполняет очередной технический шаг обработки в рамках pipeline.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
imp = connect(
    to='IMPALA',
    extra_options={'db': 'sandbox_ai'},
    driver_args={'tez.queue.name': 'ai'},
    kerberos={
        'keytab_path': '/home/jovyan/test_requests/tech.keytab',
        'use_credentials': True,
        'update_keytab': True,
    },
    user_params={'user_name': 'Shestopalov-VYur'}
)
imp._init_connection()

# %% [markdown]
# ## 3) Параметры запуска
#
# Меняем только `report_month` (первый день нужного месяца).
# `month_start` и `month_end` считаются автоматически.

# %% [markdown]
# ### Подробный разбор кода (ячейка 4)
#
# - Строка 1: `# Единственный параметр месяца (первый день месяца)` — Комментарий автора: поясняет ближайший блок логики.
# - Строка 2: `report_month = '2026-05-01'` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 4: `# Путь для итогового CSV` — Комментарий автора: поясняет ближайший блок логики.
# - Строка 5: `output_csv_path = './datamart_month_acquiring_2026_05.csv'` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 7: `report_month_ts = pd.to_datetime(report_month)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 8: `month_start = report_month_ts.strftime('%Y-%m-%d')` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 9: `month_end = (report_month_ts + pd.offsets.MonthEnd(1)).strftime('%Y-%m-%d')` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 10: `report_month_label = report_month_ts.strftime('%Y-%m')` — Сохраняет результат текущего шага в переменную для следующих операций.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
# Единственный параметр месяца (первый день месяца)
report_month = '2026-05-01'

# Путь для итогового CSV
output_csv_path = './datamart_month_acquiring_2026_05.csv'

report_month_ts = pd.to_datetime(report_month)
month_start = report_month_ts.strftime('%Y-%m-%d')
month_end = (report_month_ts + pd.offsets.MonthEnd(1)).strftime('%Y-%m-%d')
report_month_label = report_month_ts.strftime('%Y-%m')

# %% [markdown]
# ## Сборка витрины по MVP-атрибутам
#
# Последовательный SQL-pipeline от SA-периметра до финальной витрины.

# %% [markdown]
# ### Подробный разбор кода (ячейка 5)
#
# - Строка 1: `# Переход к расчетным шагам сборки витрины.` — Комментарий автора: поясняет ближайший блок логики.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
# Переход к расчетным шагам сборки витрины.

# %% [markdown]
# ### 4.1) Функции нормализации
#
# Отдельная ячейка с функциями для очистки и приведения данных.

# %% [markdown]
# ### Подробный разбор кода (ячейка 6)
#
# - Строка 1: `def normalize_inn(v):` — Определяет функцию, чтобы переиспользовать логику ниже в нескольких местах.
# - Строка 2: `    if pd.isna(v):` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 3: `        return None` — Возвращает итоговое значение из функции.
# - Строка 4: `    s = re.sub(r'[^0-9]', '', str(v).strip())` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 5: `    return s or None` — Возвращает итоговое значение из функции.
# - Строка 8: `def normalize_contract(v):` — Определяет функцию, чтобы переиспользовать логику ниже в нескольких местах.
# - Строка 9: `    if pd.isna(v):` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 10: `        return None` — Возвращает итоговое значение из функции.
# - Строка 11: `    s = str(v).strip()` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 12: `    return s if s else None` — Возвращает итоговое значение из функции.
# - Строка 15: `def to_decimal_or_none(v):` — Определяет функцию, чтобы переиспользовать логику ниже в нескольких местах.
# - Строка 16: `    if pd.isna(v):` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 17: `        return None` — Возвращает итоговое значение из функции.
# - Строка 18: `    if isinstance(v, Decimal):` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 19: `        return v` — Возвращает итоговое значение из функции.
# - Строка 20: `    try:` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 21: `        return Decimal(str(v).strip().replace(',', '.'))` — Возвращает итоговое значение из функции.
# - Строка 22: `    except (InvalidOperation, ValueError):` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 23: `        return None` — Возвращает итоговое значение из функции.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
def normalize_inn(v):
    if pd.isna(v):
        return None
    s = re.sub(r'[^0-9]', '', str(v).strip())
    return s or None


def normalize_contract(v):
    if pd.isna(v):
        return None
    s = str(v).strip()
    return s if s else None


def to_decimal_or_none(v):
    if pd.isna(v):
        return None
    if isinstance(v, Decimal):
        return v
    try:
        return Decimal(str(v).strip().replace(',', '.'))
    except (InvalidOperation, ValueError):
        return None

# %% [markdown]
# ### 4.2) SA-периметр (базовый слой)
#
# Берем из Озера клиентов и договоры, активные в выбранном месяце, и получаем базовый периметр для последующего обогащения.

# %% [markdown]
# ### Подробный разбор кода (ячейка 7)
#
# - Строка 1: `sql_sa_perimeter = f"""` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 2: `select distinct` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 3: `  cast(a.n_agr as string) as n_agr,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 4: `  cast(a.abs_agr_id as string) as agr_id,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 5: `  cast(a.n_cmp_client as string) as n_cmp_client,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 6: `  cast(a.c_agr_number as string) as contract_number,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 7: `  cast(a.d_valid_from as date) as d_valid_from,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 8: `  cast(a.d_valid_to as date) as d_valid_to,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 9: `  regexp_replace(trim(cast(c.c_inn as string)), '[^0-9]', '') as inn,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 10: `  cast(c.c_cmp_name as string) as company_name` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 11: `from ods_alpha.scd1_agreements a` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 12: `join ods_alpha.scd1_companies c` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 13: `  on c.n_cmp = a.n_cmp_client` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 14: `where upper(trim(cast(a.acq_class as string))) = 'SA'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 15: `  and cast(a.d_valid_from as date) <= cast('{month_end}' as date)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 16: `  and (a.d_valid_to is null or cast(a.d_valid_to as date) >= cast('{month_start}' as date))` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 17: `  and coalesce(a.ods_deleted_flg, '0') <> '1'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 18: `  and coalesce(c.ods_deleted_flg, '0') <> '1'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 19: `  and c.c_inn is not null` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 20: `"""` — Открывает/закрывает многострочный блок (обычно SQL-текст).
# - Строка 22: `with imp:` — Открывает контекст подключения к Impala для безопасного выполнения SQL.
# - Строка 23: `    imp.execute('set MEM_LIMIT=8g')` — Выполняет служебную команду в Impala (например, настройку лимита памяти).
# - Строка 24: `    sa_df = imp.fetch(sql_sa_perimeter)` — Выполняет SQL-запрос и загружает результат в DataFrame.
# - Строка 26: `if sa_df is None:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 27: `    sa_df = pd.DataFrame()` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 29: `if not sa_df.empty:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 30: `    sa_df['inn'] = sa_df['inn'].map(normalize_inn)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 31: `    sa_df['contract_number'] = sa_df['contract_number'].map(normalize_contract)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 33: `sa_rows_cnt = len(sa_df)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 34: `sa_inn_unique_cnt = sa_df['inn'].dropna().astype(str).nunique() if 'inn' in sa_df.columns else 0` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 35: `print(f'Записей в SA-периметре: {sa_rows_cnt:,}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 36: `print(f'Уникальных ИНН в SA-периметре: {sa_inn_unique_cnt:,}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 38: `sa_df.head(5)` — Выполняет очередной технический шаг обработки в рамках pipeline.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
sql_sa_perimeter = f"""
select distinct
  cast(a.n_agr as string) as n_agr,
  cast(a.abs_agr_id as string) as agr_id,
  cast(a.n_cmp_client as string) as n_cmp_client,
  cast(a.c_agr_number as string) as contract_number,
  cast(a.d_valid_from as date) as d_valid_from,
  cast(a.d_valid_to as date) as d_valid_to,
  regexp_replace(trim(cast(c.c_inn as string)), '[^0-9]', '') as inn,
  cast(c.c_cmp_name as string) as company_name
from ods_alpha.scd1_agreements a
join ods_alpha.scd1_companies c
  on c.n_cmp = a.n_cmp_client
where upper(trim(cast(a.acq_class as string))) = 'SA'
  and cast(a.d_valid_from as date) <= cast('{month_end}' as date)
  and (a.d_valid_to is null or cast(a.d_valid_to as date) >= cast('{month_start}' as date))
  and coalesce(a.ods_deleted_flg, '0') <> '1'
  and coalesce(c.ods_deleted_flg, '0') <> '1'
  and c.c_inn is not null
"""

with imp:
    imp.execute('set MEM_LIMIT=8g')
    sa_df = imp.fetch(sql_sa_perimeter)

if sa_df is None:
    sa_df = pd.DataFrame()

if not sa_df.empty:
    sa_df['inn'] = sa_df['inn'].map(normalize_inn)
    sa_df['contract_number'] = sa_df['contract_number'].map(normalize_contract)

sa_rows_cnt = len(sa_df)
sa_inn_unique_cnt = sa_df['inn'].dropna().astype(str).nunique() if 'inn' in sa_df.columns else 0
print(f'Записей в SA-периметре: {sa_rows_cnt:,}')
print(f'Уникальных ИНН в SA-периметре: {sa_inn_unique_cnt:,}')

sa_df.head(5)

# %% [markdown]
# ### 4.3) Маппинг INN -> CDI
#
# Для ИНН из периметра ищем актуальный OCRM `row_id` и связываем его с `cdi_id` через `cdiul.ext_id_org`.

# %% [markdown]
# ### Подробный разбор кода (ячейка 8)
#
# - Строка 1: `inn_values = sorted([x for x in sa_df.get('inn', pd.Series(dtype=object)).dropna().astype(str).unique().tolist() if x])` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 2: `inn_sql_list = ', '.join([f"'{x}'" for x in inn_values]) if inn_values else "''"` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 4: `sql_cdi = f"""` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 5: `with ocrm_current as (` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 6: `  select` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 7: `    regexp_replace(trim(cast(soe.x_inn as string)), '[^0-9]', '') as inn,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 8: `    cast(soe.row_id as string) as row_id,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 9: `    trim(cast(soe.x_area_resp as string)) as x_area_resp_norm,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 10: `    lower(trim(cast(soe.x_area_resp as string))) as x_area_resp_lc,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 11: `    case` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 12: `      when lower(trim(cast(soe.x_area_resp as string))) like 'дммб%' then 'ДМ'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 13: `      when lower(trim(cast(soe.x_area_resp as string))) like 'дмсб(ми%' then 'ДМ'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 14: `      when lower(trim(cast(soe.x_area_resp as string))) like 'дмсб (ми%' then 'ДМ'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 15: `      when lower(trim(cast(soe.x_area_resp as string))) like 'дмсб(ма%' then 'ДМСБ'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 16: `      when lower(trim(cast(soe.x_area_resp as string))) like 'дмсб (ма%' then 'ДМСБ'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 17: `      when lower(trim(cast(soe.x_area_resp as string))) like 'дмсб(ср%' then 'ДМСБ'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 18: `      when lower(trim(cast(soe.x_area_resp as string))) like 'дмсб (ср%' then 'ДМСБ'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 19: `      when lower(trim(cast(soe.x_area_resp as string))) like 'дсб%' then 'ДМСБ'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 20: `      when lower(trim(cast(soe.x_area_resp as string))) like 'дкб%' then 'ДКБ'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 21: `      when lower(trim(cast(soe.x_area_resp as string))) like 'дрпа%' then 'ДРПА'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 22: `      when lower(trim(cast(soe.x_area_resp as string))) like 'дра%' then 'ДРПА'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 23: `      when lower(trim(cast(soe.x_area_resp as string))) like 'не подл%' then 'Не подлежит сегментации'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 24: `      when lower(trim(cast(soe.x_area_resp as string))) like 'не под%' then 'Не подлежит сегментации'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 25: `      when nullif(trim(cast(soe.x_area_resp as string)), '') is null then null` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 26: `      else null` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 27: `    end as ssp_ocrm,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 28: `    row_number() over (` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 29: `      partition by regexp_replace(trim(cast(soe.x_inn as string)), '[^0-9]', '')` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 30: `      order by cast(soe.created as timestamp) desc,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 31: `               cast(soe.row_id as string) desc` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 32: `    ) as rn` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 33: `  from ocrm_ul.s_org_ext soe` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 34: `  where regexp_replace(trim(cast(soe.x_inn as string)), '[^0-9]', '') in ({inn_sql_list})` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 35: `    and coalesce(soe.x_removed_flg, 'N') = 'N'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 36: `    and coalesce(soe.x_duplicate_flg, 'N') = 'N'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 37: `),` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 38: `ocrm_one as (` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 39: `  select inn, row_id, ssp_ocrm, x_area_resp_norm` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 40: `  from ocrm_current` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 41: `  where rn = 1` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 42: `)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 43: `select` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 44: `  o.inn,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 45: `  o.ssp_ocrm,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 46: `  o.x_area_resp_norm,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 47: `  cast(e.party_id as string) as cdi_id` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 48: `from ocrm_one o` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 49: `left join cdiul.ext_id_org e` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 50: `  on cast(e.cmo_ext_party_source_id as string) = o.row_id` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 51: ` and upper(cast(e.cmo_ext_source_system as string)) like 'OCRM%'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 52: `"""` — Открывает/закрывает многострочный блок (обычно SQL-текст).
# - Строка 54: `with imp:` — Открывает контекст подключения к Impala для безопасного выполнения SQL.
# - Строка 55: `    imp.execute('set MEM_LIMIT=8g')` — Выполняет служебную команду в Impala (например, настройку лимита памяти).
# - Строка 56: `    cdi_map_df = imp.fetch(sql_cdi)` — Выполняет SQL-запрос и загружает результат в DataFrame.
# - Строка 58: `if cdi_map_df is None:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 59: `    cdi_map_df = pd.DataFrame(columns=['inn', 'ssp_ocrm', 'x_area_resp_norm', 'cdi_id'])` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 61: `if not cdi_map_df.empty:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 62: `    cdi_map_df['inn'] = cdi_map_df['inn'].map(normalize_inn)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 63: `    cdi_map_df['cdi_id'] = cdi_map_df['cdi_id'].astype(str)` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 65: `    # Финальный контроль канонических сегментов` — Комментарий автора: поясняет ближайший блок логики.
# - Строка 66: `    allowed_ssp_values = {'ДМ', 'ДМСБ', 'ДКБ', 'ДРПА', 'Не подлежит сегментации'}` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 67: `    cdi_map_df['ssp_ocrm'] = cdi_map_df['ssp_ocrm'].where(cdi_map_df['ssp_ocrm'].isin(allowed_ssp_values), None)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 69: `    cdi_map_df = cdi_map_df.drop_duplicates(subset=['inn'], keep='first')` — Убирает дубли, чтобы сохранить уникальность по выбранному ключу.
# - Строка 71: `cdi_map_df.head(5)` — Выполняет очередной технический шаг обработки в рамках pipeline.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
inn_values = sorted([x for x in sa_df.get('inn', pd.Series(dtype=object)).dropna().astype(str).unique().tolist() if x])
inn_sql_list = ', '.join([f"'{x}'" for x in inn_values]) if inn_values else "''"

sql_cdi = f"""
with ocrm_current as (
  select
    regexp_replace(trim(cast(soe.x_inn as string)), '[^0-9]', '') as inn,
    cast(soe.row_id as string) as row_id,
    trim(cast(soe.x_area_resp as string)) as x_area_resp_norm,
    lower(trim(cast(soe.x_area_resp as string))) as x_area_resp_lc,
    case
      when lower(trim(cast(soe.x_area_resp as string))) like 'дммб%' then 'ДМ'
      when lower(trim(cast(soe.x_area_resp as string))) like 'дмсб(ми%' then 'ДМ'
      when lower(trim(cast(soe.x_area_resp as string))) like 'дмсб (ми%' then 'ДМ'
      when lower(trim(cast(soe.x_area_resp as string))) like 'дмсб(ма%' then 'ДМСБ'
      when lower(trim(cast(soe.x_area_resp as string))) like 'дмсб (ма%' then 'ДМСБ'
      when lower(trim(cast(soe.x_area_resp as string))) like 'дмсб(ср%' then 'ДМСБ'
      when lower(trim(cast(soe.x_area_resp as string))) like 'дмсб (ср%' then 'ДМСБ'
      when lower(trim(cast(soe.x_area_resp as string))) like 'дсб%' then 'ДМСБ'
      when lower(trim(cast(soe.x_area_resp as string))) like 'дкб%' then 'ДКБ'
      when lower(trim(cast(soe.x_area_resp as string))) like 'дрпа%' then 'ДРПА'
      when lower(trim(cast(soe.x_area_resp as string))) like 'дра%' then 'ДРПА'
      when lower(trim(cast(soe.x_area_resp as string))) like 'не подл%' then 'Не подлежит сегментации'
      when lower(trim(cast(soe.x_area_resp as string))) like 'не под%' then 'Не подлежит сегментации'
      when nullif(trim(cast(soe.x_area_resp as string)), '') is null then null
      else null
    end as ssp_ocrm,
    row_number() over (
      partition by regexp_replace(trim(cast(soe.x_inn as string)), '[^0-9]', '')
      order by cast(soe.created as timestamp) desc,
               cast(soe.row_id as string) desc
    ) as rn
  from ocrm_ul.s_org_ext soe
  where regexp_replace(trim(cast(soe.x_inn as string)), '[^0-9]', '') in ({inn_sql_list})
    and coalesce(soe.x_removed_flg, 'N') = 'N'
    and coalesce(soe.x_duplicate_flg, 'N') = 'N'
),
ocrm_one as (
  select inn, row_id, ssp_ocrm, x_area_resp_norm
  from ocrm_current
  where rn = 1
)
select
  o.inn,
  o.ssp_ocrm,
  o.x_area_resp_norm,
  cast(e.party_id as string) as cdi_id
from ocrm_one o
left join cdiul.ext_id_org e
  on cast(e.cmo_ext_party_source_id as string) = o.row_id
 and upper(cast(e.cmo_ext_source_system as string)) like 'OCRM%'
"""

with imp:
    imp.execute('set MEM_LIMIT=8g')
    cdi_map_df = imp.fetch(sql_cdi)

if cdi_map_df is None:
    cdi_map_df = pd.DataFrame(columns=['inn', 'ssp_ocrm', 'x_area_resp_norm', 'cdi_id'])

if not cdi_map_df.empty:
    cdi_map_df['inn'] = cdi_map_df['inn'].map(normalize_inn)
    cdi_map_df['cdi_id'] = cdi_map_df['cdi_id'].astype(str)

    # Финальный контроль канонических сегментов
    allowed_ssp_values = {'ДМ', 'ДМСБ', 'ДКБ', 'ДРПА', 'Не подлежит сегментации'}
    cdi_map_df['ssp_ocrm'] = cdi_map_df['ssp_ocrm'].where(cdi_map_df['ssp_ocrm'].isin(allowed_ssp_values), None)

    cdi_map_df = cdi_map_df.drop_duplicates(subset=['inn'], keep='first')

cdi_map_df.head(5)

# %% [markdown]
# ### 4.4) Маппинг CDI -> CFT
#
# Для найденных `cdi_id` получаем соответствующие `cft_id`, чтобы перейти к операционным и финансовым метрикам R2.

# %% [markdown]
# ### Подробный разбор кода (ячейка 9)
#
# - Строка 1: `cdi_values = sorted([x for x in cdi_map_df.get('cdi_id', pd.Series(dtype=object)).dropna().astype(str).unique().tolist() if x])` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 2: `cdi_sql_list = ', '.join([f"'{x}'" for x in cdi_values]) if cdi_values else "''"` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 4: `sql_cft = f"""` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 5: `select` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 6: `  cast(e.party_id as string) as cdi_id,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 7: `  cast(e.cmo_ext_party_source_id as string) as cft_id` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 8: `from cdiul.ext_id_org e` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 9: `where cast(e.party_id as string) in ({cdi_sql_list})` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 10: `  and upper(cast(e.cmo_ext_source_system as string)) like 'CFT%'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 11: `"""` — Открывает/закрывает многострочный блок (обычно SQL-текст).
# - Строка 13: `with imp:` — Открывает контекст подключения к Impala для безопасного выполнения SQL.
# - Строка 14: `    imp.execute('set MEM_LIMIT=8g')` — Выполняет служебную команду в Impala (например, настройку лимита памяти).
# - Строка 15: `    cft_map_df = imp.fetch(sql_cft)` — Выполняет SQL-запрос и загружает результат в DataFrame.
# - Строка 17: `if cft_map_df is None:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 18: `    cft_map_df = pd.DataFrame(columns=['cdi_id', 'cft_id'])` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 20: `if not cft_map_df.empty:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 21: `    cft_map_df['cdi_id'] = cft_map_df['cdi_id'].astype(str)` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 22: `    cft_map_df['cft_id'] = cft_map_df['cft_id'].astype(str)` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 23: `    cft_map_df = cft_map_df.drop_duplicates(subset=['cdi_id'], keep='first')` — Убирает дубли, чтобы сохранить уникальность по выбранному ключу.
# - Строка 25: `cft_map_df.head(5)` — Выполняет очередной технический шаг обработки в рамках pipeline.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
cdi_values = sorted([x for x in cdi_map_df.get('cdi_id', pd.Series(dtype=object)).dropna().astype(str).unique().tolist() if x])
cdi_sql_list = ', '.join([f"'{x}'" for x in cdi_values]) if cdi_values else "''"

sql_cft = f"""
select
  cast(e.party_id as string) as cdi_id,
  cast(e.cmo_ext_party_source_id as string) as cft_id
from cdiul.ext_id_org e
where cast(e.party_id as string) in ({cdi_sql_list})
  and upper(cast(e.cmo_ext_source_system as string)) like 'CFT%'
"""

with imp:
    imp.execute('set MEM_LIMIT=8g')
    cft_map_df = imp.fetch(sql_cft)

if cft_map_df is None:
    cft_map_df = pd.DataFrame(columns=['cdi_id', 'cft_id'])

if not cft_map_df.empty:
    cft_map_df['cdi_id'] = cft_map_df['cdi_id'].astype(str)
    cft_map_df['cft_id'] = cft_map_df['cft_id'].astype(str)
    cft_map_df = cft_map_df.drop_duplicates(subset=['cdi_id'], keep='first')

cft_map_df.head(5)

# %% [markdown]
# ### 4.5) Операционные и транзакционные атрибуты
#
# Считаем метрики на уровне компании (`retl_cnt`, `term_cnt`, `amortization`) и договора (`trx_cnt`, `trx_sum`, `commission_from_ops`, `int_component`).

# %% [markdown]
# ### Подробный разбор кода (ячейка 10)
#
# - Строка 1: `# 4.5.1) Company-level metrics (retl_cnt, term_cnt, amortization)` — Комментарий автора: поясняет ближайший блок логики.
# - Строка 2: `cmp_ids = sorted(sa_df.get('n_cmp_client', pd.Series(dtype=object)).dropna().astype(str).unique().tolist())` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 3: `cmp_in = ', '.join([f"'{x}'" for x in cmp_ids]) if cmp_ids else "''"` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 5: `sql_cmp = f"""` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 6: `with m as (` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 7: `  select` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 8: `    cast(n_cmp as string) as n_cmp_client,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 9: `    cast(c_nmrc as string) as c_nmrc,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 10: `    cast(n_mcc as string) as n_mcc` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 11: `  from ods_alpha.scd1_merchants` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 12: `  where cast(n_cmp as string) in ({cmp_in})` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 13: `    and c_nmrc is not null` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 14: `),` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 15: `retl as (` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 16: `  select n_cmp_client,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 17: `         count(distinct c_nmrc) as retl_cnt` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 18: `  from m` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 19: `  group by n_cmp_client` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 20: `),` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 21: `term as (` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 22: `  select m.n_cmp_client,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 23: `         count(distinct t.c_nter) as term_cnt` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 24: `  from m` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 25: `  join ods_alpha.scd1_pos_terminals t` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 26: `    on t.c_nmrc = m.c_nmrc and t.c_nter is not null` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 27: `  group by m.n_cmp_client` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 28: `),` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 29: `amort as (` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 30: `  select m.n_cmp_client,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 31: `         sum(coalesce(cast(am.amortization_monthly as double), 0.0)) as amortization` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 32: `  from m` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 33: `  join ods_alpha.scd1_pos_terminals t` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 34: `    on t.c_nmrc = m.c_nmrc and t.c_nter is not null` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 35: `  left join sandbox_ai.shestopalov_terminal_amortization_oneoff am` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 36: `    on cast(am.c_nter as string) = cast(t.c_nter as string)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 37: `  group by m.n_cmp_client` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 38: `)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 39: `select` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 40: `  coalesce(r.n_cmp_client, t.n_cmp_client, a.n_cmp_client) as n_cmp_client,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 41: `  r.retl_cnt,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 42: `  t.term_cnt,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 43: `  a.amortization` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 44: `from retl r` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 45: `full outer join term t on t.n_cmp_client = r.n_cmp_client` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 46: `full outer join amort a on a.n_cmp_client = coalesce(r.n_cmp_client, t.n_cmp_client)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 47: `"""` — Открывает/закрывает многострочный блок (обычно SQL-текст).
# - Строка 49: `with imp:` — Открывает контекст подключения к Impala для безопасного выполнения SQL.
# - Строка 50: `    imp.execute('set MEM_LIMIT=8g')` — Выполняет служебную команду в Impala (например, настройку лимита памяти).
# - Строка 51: `    cmp_df = imp.fetch(sql_cmp)` — Выполняет SQL-запрос и загружает результат в DataFrame.
# - Строка 53: `if cmp_df is None:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 54: `    cmp_df = pd.DataFrame(columns=['n_cmp_client', 'retl_cnt', 'term_cnt', 'amortization'])` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 56: `if not cmp_df.empty:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 57: `    cmp_df['n_cmp_client'] = cmp_df['n_cmp_client'].astype(str)` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 59: `cmp_df.head(5)` — Выполняет очередной технический шаг обработки в рамках pipeline.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
# 4.5.1) Company-level metrics (retl_cnt, term_cnt, amortization)
cmp_ids = sorted(sa_df.get('n_cmp_client', pd.Series(dtype=object)).dropna().astype(str).unique().tolist())
cmp_in = ', '.join([f"'{x}'" for x in cmp_ids]) if cmp_ids else "''"

sql_cmp = f"""
with m as (
  select
    cast(n_cmp as string) as n_cmp_client,
    cast(c_nmrc as string) as c_nmrc,
    cast(n_mcc as string) as n_mcc
  from ods_alpha.scd1_merchants
  where cast(n_cmp as string) in ({cmp_in})
    and c_nmrc is not null
),
retl as (
  select n_cmp_client,
         count(distinct c_nmrc) as retl_cnt
  from m
  group by n_cmp_client
),
term as (
  select m.n_cmp_client,
         count(distinct t.c_nter) as term_cnt
  from m
  join ods_alpha.scd1_pos_terminals t
    on t.c_nmrc = m.c_nmrc and t.c_nter is not null
  group by m.n_cmp_client
),
amort as (
  select m.n_cmp_client,
         sum(coalesce(cast(am.amortization_monthly as double), 0.0)) as amortization
  from m
  join ods_alpha.scd1_pos_terminals t
    on t.c_nmrc = m.c_nmrc and t.c_nter is not null
  left join sandbox_ai.shestopalov_terminal_amortization_oneoff am
    on cast(am.c_nter as string) = cast(t.c_nter as string)
  group by m.n_cmp_client
)
select
  coalesce(r.n_cmp_client, t.n_cmp_client, a.n_cmp_client) as n_cmp_client,
  r.retl_cnt,
  t.term_cnt,
  a.amortization
from retl r
full outer join term t on t.n_cmp_client = r.n_cmp_client
full outer join amort a on a.n_cmp_client = coalesce(r.n_cmp_client, t.n_cmp_client)
"""

with imp:
    imp.execute('set MEM_LIMIT=8g')
    cmp_df = imp.fetch(sql_cmp)

if cmp_df is None:
    cmp_df = pd.DataFrame(columns=['n_cmp_client', 'retl_cnt', 'term_cnt', 'amortization'])

if not cmp_df.empty:
    cmp_df['n_cmp_client'] = cmp_df['n_cmp_client'].astype(str)

cmp_df.head(5)

# %% [markdown]
# ### 4.5.2) TRX-метрики по договору
#
# Отдельный шаг расчета транзакционных метрик по `n_agr` (проще отладка при ошибках в `trx`-логике).

# %% [markdown]
# ### Подробный разбор кода (ячейка 11)
#
# - Строка 1: `# 4.5.2) Transaction metrics by agreement (trx_cnt, trx_sum, commission_from_ops, int_component)` — Комментарий автора: поясняет ближайший блок логики.
# - Строка 2: `n_agrs = sorted(sa_df.get('n_agr', pd.Series(dtype=object)).dropna().astype(str).unique().tolist())` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 3: `agr_in = ', '.join([f"'{x}'" for x in n_agrs]) if n_agrs else "''"` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 5: `sql_trx = f"""` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 6: `with trx_base as (` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 7: `  select` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 8: `    cast(t.n_trx as string) as n_trx,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 9: `    cast(t.n_amt_src as double) as n_amt_src` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 10: `  from ods_alpha.scd1_trx t` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 11: `  left join ods_alpha.scd1_base24_fiids fa` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 12: `    on cast(fa.c_fiid as string) = cast(t.c_fiid_acq as string)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 13: `  where to_date(cast(t.d_trx_orig as timestamp)) between cast('{month_start}' as date) and cast('{month_end}' as date)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 14: `    and t.c_nter is not null` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 15: `    and coalesce(t.ods_deleted_flg, '0') <> '1'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 16: `    and t.c_trx_class = 'SA'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 17: `    and t.c_trx_type = 'S01'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 18: `    and coalesce(t.cf_trx_stat, '') <> 'R'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 19: `    and coalesce(cast(fa.c_fiid_grp as string), 'UNKNOWN') = 'RSHB'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 20: `),` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 21: `ta as (` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 22: `  select` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 23: `    cast(n_trx as string) as n_trx,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 24: `    cast(n_agr as string) as n_agr,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 25: `    coalesce(cast(n_amt_tax as double), 0.0) as n_amt_tax` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 26: `  from ods_alpha.scd1_trx_acq` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 27: `  where cast(n_agr as string) in ({agr_in})` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 28: `),` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 29: `tj as (` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 30: `  select` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 31: `    ta.n_agr,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 32: `    ta.n_trx,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 33: `    tb.n_amt_src,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 34: `    ta.n_amt_tax` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 35: `  from ta` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 36: `  join trx_base tb on tb.n_trx = ta.n_trx` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 37: `)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 38: `select` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 39: `  tj.n_agr,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 40: `  count(distinct tj.n_trx) as trx_cnt,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 41: `  sum(tj.n_amt_src) as trx_sum,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 42: `  sum(tj.n_amt_tax) as commission_from_ops,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 43: `  sum(coalesce(cast(i.n_amt_fee as double), 0.0)) as int_component` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 44: `from tj` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 45: `left join ods_alpha.scd1_trx_int i on cast(i.n_trx as string) = tj.n_trx` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 46: `group by tj.n_agr` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 47: `"""` — Открывает/закрывает многострочный блок (обычно SQL-текст).
# - Строка 49: `with imp:` — Открывает контекст подключения к Impala для безопасного выполнения SQL.
# - Строка 50: `    imp.execute('set MEM_LIMIT=8g')` — Выполняет служебную команду в Impala (например, настройку лимита памяти).
# - Строка 51: `    trx_df = imp.fetch(sql_trx)` — Выполняет SQL-запрос и загружает результат в DataFrame.
# - Строка 53: `if trx_df is None:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 54: `    trx_df = pd.DataFrame(columns=['n_agr', 'trx_cnt', 'trx_sum', 'commission_from_ops', 'int_component'])` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 56: `if not trx_df.empty:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 57: `    trx_df['n_agr'] = trx_df['n_agr'].astype(str)` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 59: `trx_df.head(5)` — Выполняет очередной технический шаг обработки в рамках pipeline.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
# 4.5.2) Transaction metrics by agreement (trx_cnt, trx_sum, commission_from_ops, int_component)
n_agrs = sorted(sa_df.get('n_agr', pd.Series(dtype=object)).dropna().astype(str).unique().tolist())
agr_in = ', '.join([f"'{x}'" for x in n_agrs]) if n_agrs else "''"

sql_trx = f"""
with trx_base as (
  select
    cast(t.n_trx as string) as n_trx,
    cast(t.n_amt_src as double) as n_amt_src
  from ods_alpha.scd1_trx t
  left join ods_alpha.scd1_base24_fiids fa
    on cast(fa.c_fiid as string) = cast(t.c_fiid_acq as string)
  where to_date(cast(t.d_trx_orig as timestamp)) between cast('{month_start}' as date) and cast('{month_end}' as date)
    and t.c_nter is not null
    and coalesce(t.ods_deleted_flg, '0') <> '1'
    and t.c_trx_class = 'SA'
    and t.c_trx_type = 'S01'
    and coalesce(t.cf_trx_stat, '') <> 'R'
    and coalesce(cast(fa.c_fiid_grp as string), 'UNKNOWN') = 'RSHB'
),
ta as (
  select
    cast(n_trx as string) as n_trx,
    cast(n_agr as string) as n_agr,
    coalesce(cast(n_amt_tax as double), 0.0) as n_amt_tax
  from ods_alpha.scd1_trx_acq
  where cast(n_agr as string) in ({agr_in})
),
tj as (
  select
    ta.n_agr,
    ta.n_trx,
    tb.n_amt_src,
    ta.n_amt_tax
  from ta
  join trx_base tb on tb.n_trx = ta.n_trx
)
select
  tj.n_agr,
  count(distinct tj.n_trx) as trx_cnt,
  sum(tj.n_amt_src) as trx_sum,
  sum(tj.n_amt_tax) as commission_from_ops,
  sum(coalesce(cast(i.n_amt_fee as double), 0.0)) as int_component
from tj
left join ods_alpha.scd1_trx_int i on cast(i.n_trx as string) = tj.n_trx
group by tj.n_agr
"""

with imp:
    imp.execute('set MEM_LIMIT=8g')
    trx_df = imp.fetch(sql_trx)

if trx_df is None:
    trx_df = pd.DataFrame(columns=['n_agr', 'trx_cnt', 'trx_sum', 'commission_from_ops', 'int_component'])

if not trx_df.empty:
    trx_df['n_agr'] = trx_df['n_agr'].astype(str)

trx_df.head(5)

# %% [markdown]
# ### 4.5.3) R2-атрибуты (оргструктура и тариф)
#
# Отдельный шаг R2, чтобы ошибки по орг/тарифным полям не маскировались в общей секции.

# %% [markdown]
# ### Подробный разбор кода (ячейка 12)
#
# - Строка 1: `cft_values = sorted([x for x in cft_map_df.get('cft_id', pd.Series(dtype=object)).dropna().astype(str).unique().tolist() if x])` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 2: `cft_sql_list = ', '.join([f"'{x}'" for x in cft_values]) if cft_values else "''"` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 4: `sql_r2 = f"""` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 5: `with r2 as (` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 6: `  select` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 7: `    cast(m.id as string) as r2_id,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 8: `    cast(m.c_cl_org as string) as cft_id,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 9: `    cast(m.c_depart as string) as c_depart,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 10: `    cast(m.c_tariff_plan as string) as c_tariff_plan` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 11: `  from ods.scd1_z_r2_ip_merchants m` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 12: `  where cast(m.c_cl_org as string) in ({cft_sql_list})` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 13: `),` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 14: `fix as (` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 15: `  select` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 16: `    cast(tt.c_tariff_plan as string) as c_tariff_plan,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 17: `    max(cast(tf.c_summa as decimal(18,2))) as commission_monthly_fix` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 18: `  from ods.scd1_z_r2_tariff_tune tt` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 19: `  left join ods.scd1_z_r2_tariff_fix tf on tt.c_tariff = tf.id` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 20: `  group by cast(tt.c_tariff_plan as string)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 21: `)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 22: `select` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 23: `  r2.r2_id,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 24: `  r2.cft_id,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 25: `  cast(corp.c_register_gos_reg_num_rec as string) as ogrn,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 26: `  cast(dep.c_name as string) as vsp_name,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 27: `  cast(dep.c_num as string) as vsp_code,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 28: `  case` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 29: `    when br.c_shortlabel is null then null` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 30: `    when upper(cast(br.c_shortlabel as string)) like '%РФ%'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 31: `      then regexp_extract(cast(br.c_shortlabel as string), '^(.*?РФ)', 1)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 32: `    else cast(br.c_shortlabel as string)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 33: `  end as filial_rf,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 34: `  cast(tp.c_name as string) as tariff_name,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 35: `  cast(fix.commission_monthly_fix as decimal(18,2)) as commission_monthly` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 36: `from r2` — Импортирует библиотеку/модуль для работы текущей тетрадки.
# - Строка 37: `left join ods.scd1_z_cl_corp corp on cast(corp.id as string) = r2.cft_id` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 38: `left join ods.scd1_z_depart dep on cast(dep.id as string) = r2.c_depart` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 39: `left join ods.scd1_z_branch br on cast(br.id as string) = cast(dep.c_filial as string)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 40: `left join ods.scd1_z_r2_tariff_plan tp on cast(tp.id as string) = r2.c_tariff_plan` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 41: `left join fix on fix.c_tariff_plan = r2.c_tariff_plan` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 42: `"""` — Открывает/закрывает многострочный блок (обычно SQL-текст).
# - Строка 44: `with imp:` — Открывает контекст подключения к Impala для безопасного выполнения SQL.
# - Строка 45: `    imp.execute('set MEM_LIMIT=8g')` — Выполняет служебную команду в Impala (например, настройку лимита памяти).
# - Строка 46: `    r2_df = imp.fetch(sql_r2)` — Выполняет SQL-запрос и загружает результат в DataFrame.
# - Строка 48: `if r2_df is None:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 49: `    r2_df = pd.DataFrame(columns=['r2_id', 'cft_id', 'ogrn', 'vsp_name', 'vsp_code', 'filial_rf', 'tariff_name', 'commission_monthly'])` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 51: `if not r2_df.empty:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 52: `    for c in ['r2_id', 'cft_id', 'ogrn', 'vsp_name', 'vsp_code', 'filial_rf', 'tariff_name']:` — Цикл по набору элементов (колонки, строки, список значений и т.п.).
# - Строка 53: `        r2_df[c] = r2_df[c].astype(str)` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 55: `    r2_rows_before = len(r2_df)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 56: `    r2_df = r2_df.drop_duplicates(subset=['cft_id'], keep='first')` — Убирает дубли, чтобы сохранить уникальность по выбранному ключу.
# - Строка 57: `    r2_rows_after = len(r2_df)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 58: `    print(f'R2 строк до дедупликации по cft_id: {r2_rows_before:,}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 59: `    print(f'R2 строк после дедупликации по cft_id: {r2_rows_after:,}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 61: `r2_df.head(5)` — Выполняет очередной технический шаг обработки в рамках pipeline.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
cft_values = sorted([x for x in cft_map_df.get('cft_id', pd.Series(dtype=object)).dropna().astype(str).unique().tolist() if x])
cft_sql_list = ', '.join([f"'{x}'" for x in cft_values]) if cft_values else "''"

sql_r2 = f"""
with r2 as (
  select
    cast(m.id as string) as r2_id,
    cast(m.c_cl_org as string) as cft_id,
    cast(m.c_depart as string) as c_depart,
    cast(m.c_tariff_plan as string) as c_tariff_plan
  from ods.scd1_z_r2_ip_merchants m
  where cast(m.c_cl_org as string) in ({cft_sql_list})
),
fix as (
  select
    cast(tt.c_tariff_plan as string) as c_tariff_plan,
    max(cast(tf.c_summa as decimal(18,2))) as commission_monthly_fix
  from ods.scd1_z_r2_tariff_tune tt
  left join ods.scd1_z_r2_tariff_fix tf on tt.c_tariff = tf.id
  group by cast(tt.c_tariff_plan as string)
)
select
  r2.r2_id,
  r2.cft_id,
  cast(corp.c_register_gos_reg_num_rec as string) as ogrn,
  cast(dep.c_name as string) as vsp_name,
  cast(dep.c_num as string) as vsp_code,
  case
    when br.c_shortlabel is null then null
    when upper(cast(br.c_shortlabel as string)) like '%РФ%'
      then regexp_extract(cast(br.c_shortlabel as string), '^(.*?РФ)', 1)
    else cast(br.c_shortlabel as string)
  end as filial_rf,
  cast(tp.c_name as string) as tariff_name,
  cast(fix.commission_monthly_fix as decimal(18,2)) as commission_monthly
from r2
left join ods.scd1_z_cl_corp corp on cast(corp.id as string) = r2.cft_id
left join ods.scd1_z_depart dep on cast(dep.id as string) = r2.c_depart
left join ods.scd1_z_branch br on cast(br.id as string) = cast(dep.c_filial as string)
left join ods.scd1_z_r2_tariff_plan tp on cast(tp.id as string) = r2.c_tariff_plan
left join fix on fix.c_tariff_plan = r2.c_tariff_plan
"""

with imp:
    imp.execute('set MEM_LIMIT=8g')
    r2_df = imp.fetch(sql_r2)

if r2_df is None:
    r2_df = pd.DataFrame(columns=['r2_id', 'cft_id', 'ogrn', 'vsp_name', 'vsp_code', 'filial_rf', 'tariff_name', 'commission_monthly'])

if not r2_df.empty:
    for c in ['r2_id', 'cft_id', 'ogrn', 'vsp_name', 'vsp_code', 'filial_rf', 'tariff_name']:
        r2_df[c] = r2_df[c].astype(str)

    r2_rows_before = len(r2_df)
    r2_df = r2_df.drop_duplicates(subset=['cft_id'], keep='first')
    r2_rows_after = len(r2_df)
    print(f'R2 строк до дедупликации по cft_id: {r2_rows_before:,}')
    print(f'R2 строк после дедупликации по cft_id: {r2_rows_after:,}')

r2_df.head(5)

# %% [markdown]
# ### 4.6) Финальная сборка MVP-витрины
#
# Объединяем SA, CDI, CFT, CMP, TRX и R2 в итоговый датасет.

# %% [markdown]
# ### Подробный разбор кода (ячейка 13)
#
# - Строка 1: `base_df = sa_df.copy()` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 2: `print(f'Строк на старте (SA): {len(base_df):,}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 4: `if not cdi_map_df.empty and not base_df.empty:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 5: `    before_rows = len(base_df)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 6: `    base_df = base_df.merge(cdi_map_df[['inn', 'cdi_id', 'ssp_ocrm']], on='inn', how='left')` — Объединяет DataFrame по ключам для обогащения витрины атрибутами.
# - Строка 7: `    print(f'После merge INN->CDI: {before_rows:,} -> {len(base_df):,}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 8: `else:` — Альтернативная ветка, если условия выше не выполнены.
# - Строка 9: `    base_df['cdi_id'] = None` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 10: `    base_df['ssp_ocrm'] = None` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 12: `if not cft_map_df.empty and not base_df.empty:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 13: `    before_rows = len(base_df)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 14: `    base_df = base_df.merge(cft_map_df[['cdi_id', 'cft_id']], on='cdi_id', how='left')` — Объединяет DataFrame по ключам для обогащения витрины атрибутами.
# - Строка 15: `    print(f'После merge CDI->CFT: {before_rows:,} -> {len(base_df):,}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 16: `else:` — Альтернативная ветка, если условия выше не выполнены.
# - Строка 17: `    base_df['cft_id'] = None` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 19: `if not r2_df.empty and not base_df.empty:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 20: `    before_rows = len(base_df)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 21: `    base_df = base_df.merge(r2_df, on='cft_id', how='left')` — Объединяет DataFrame по ключам для обогащения витрины атрибутами.
# - Строка 22: `    print(f'После merge CFT->R2: {before_rows:,} -> {len(base_df):,}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 23: `else:` — Альтернативная ветка, если условия выше не выполнены.
# - Строка 24: `    for col in ['r2_id', 'commission_monthly', 'ogrn', 'filial_rf', 'vsp_name', 'vsp_code', 'tariff_name']:` — Цикл по набору элементов (колонки, строки, список значений и т.п.).
# - Строка 25: `        base_df[col] = None` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 27: `if not cmp_df.empty and not base_df.empty:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 28: `    before_rows = len(base_df)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 29: `    base_df = base_df.merge(cmp_df[['n_cmp_client', 'retl_cnt', 'term_cnt', 'amortization']], on='n_cmp_client', how='left')` — Объединяет DataFrame по ключам для обогащения витрины атрибутами.
# - Строка 30: `    print(f'После merge company metrics: {before_rows:,} -> {len(base_df):,}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 31: `else:` — Альтернативная ветка, если условия выше не выполнены.
# - Строка 32: `    for col in ['retl_cnt', 'term_cnt', 'amortization']:` — Цикл по набору элементов (колонки, строки, список значений и т.п.).
# - Строка 33: `        base_df[col] = None` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 35: `if not trx_df.empty and not base_df.empty:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 36: `    before_rows = len(base_df)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 37: `    base_df = base_df.merge(trx_df[['n_agr', 'trx_cnt', 'trx_sum', 'commission_from_ops', 'int_component']], on='n_agr', how='left')` — Объединяет DataFrame по ключам для обогащения витрины атрибутами.
# - Строка 38: `    print(f'После merge TRX metrics: {before_rows:,} -> {len(base_df):,}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 39: `else:` — Альтернативная ветка, если условия выше не выполнены.
# - Строка 40: `    for col in ['trx_cnt', 'trx_sum', 'commission_from_ops', 'int_component']:` — Цикл по набору элементов (колонки, строки, список значений и т.п.).
# - Строка 41: `        base_df[col] = None` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 43: `if 'agr_id' not in base_df.columns:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 44: `    base_df['agr_id'] = None` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 45: `if 'r2_id' not in base_df.columns:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 46: `    base_df['r2_id'] = None` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 48: `agr_id_before_fill = base_df['agr_id'].notna() & (base_df['agr_id'].astype(str).str.strip() != '')` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 49: `base_df['agr_id_source'] = 'sa'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 50: `fallback_mask = (~agr_id_before_fill) & base_df['r2_id'].notna() & (base_df['r2_id'].astype(str).str.strip() != '')` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 51: `base_df.loc[fallback_mask, 'agr_id'] = base_df.loc[fallback_mask, 'r2_id']` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 52: `base_df.loc[fallback_mask, 'agr_id_source'] = 'r2_fallback'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 54: `agr_id_after_fill = base_df['agr_id'].notna() & (base_df['agr_id'].astype(str).str.strip() != '')` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 55: `agr_fill_before_pct = round(100.0 * agr_id_before_fill.mean(), 2) if len(base_df) else 0.0` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 56: `agr_fill_after_pct = round(100.0 * agr_id_after_fill.mean(), 2) if len(base_df) else 0.0` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 57: `agr_fallback_rows = int(fallback_mask.sum())` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 58: `print(f'Заполняемость agr_id до fallback: {agr_fill_before_pct}%')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 59: `print(f'Заполняемость agr_id после fallback: {agr_fill_after_pct}%')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 60: `print(f'Строк, где применен fallback agr_id <- r2_id: {agr_fallback_rows:,}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 62: `commission_from_ops_num = pd.to_numeric(base_df.get('commission_from_ops'), errors='coerce').fillna(0)` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 63: `commission_monthly_num = pd.to_numeric(base_df.get('commission_monthly'), errors='coerce').fillna(0)` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 64: `int_component_num = pd.to_numeric(base_df.get('int_component'), errors='coerce').fillna(0)` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 65: `amortization_num = pd.to_numeric(base_df.get('amortization'), errors='coerce').fillna(0)` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 67: `base_df['commission_total'] = commission_from_ops_num + commission_monthly_num` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 69: `term_cnt_num = pd.to_numeric(base_df.get('term_cnt'), errors='coerce')` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 70: `retl_cnt_num = pd.to_numeric(base_df.get('retl_cnt'), errors='coerce')` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 71: `aur_units = term_cnt_num.where(term_cnt_num.notna() & (term_cnt_num > 0), retl_cnt_num)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 72: `base_df['aur'] = aur_units * 1926` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 74: `aur_num = pd.to_numeric(base_df.get('aur'), errors='coerce').fillna(0)` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 75: `base_df['chod'] = base_df['commission_total'] - int_component_num` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 76: `base_df['fin_result'] = base_df['chod'] - aur_num - amortization_num` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 77: `base_df['report_month'] = report_month_label` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 79: `mvp_columns = [` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 80: `    'report_month', 'inn', 'company_name',` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 81: `    'agr_id', 'n_agr', 'contract_number', 'd_valid_from', 'd_valid_to',` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 82: `    'cdi_id', 'ssp_ocrm', 'ogrn', 'filial_rf', 'vsp_name', 'vsp_code', 'tariff_name',` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 83: `    'retl_cnt', 'term_cnt', 'trx_cnt', 'trx_sum',` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 84: `    'commission_from_ops', 'commission_monthly', 'int_component', 'commission_total',` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 85: `    'aur', 'amortization', 'chod', 'fin_result'` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 86: `]` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 88: `for col in mvp_columns:` — Цикл по набору элементов (колонки, строки, список значений и т.п.).
# - Строка 89: `    if col not in base_df.columns:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 90: `        base_df[col] = None` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 92: `for col in ['trx_sum', 'commission_from_ops', 'commission_monthly', 'int_component', 'commission_total', 'aur', 'amortization', 'chod', 'fin_result']:` — Цикл по набору элементов (колонки, строки, список значений и т.п.).
# - Строка 93: `    if col in base_df.columns:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 94: `        base_df[col] = base_df[col].map(to_decimal_or_none)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 96: `for col in ['retl_cnt', 'term_cnt', 'trx_cnt']:` — Цикл по набору элементов (колонки, строки, список значений и т.п.).
# - Строка 97: `    if col in base_df.columns:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 98: `        base_df[col] = pd.to_numeric(base_df[col], errors='coerce').astype('Int64')` — Приводит тип данных к корректному формату для расчета и выгрузки.
# - Строка 100: `final_df = base_df[mvp_columns].copy()` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 102: `for forbidden_col in ['n_cmp_client', 'key_tier', 'dq_block_reason', 'r2_id', 'agr_id_source']:` — Цикл по набору элементов (колонки, строки, список значений и т.п.).
# - Строка 103: `    if forbidden_col in final_df.columns:` — Проверяет условие и определяет, какая ветка кода выполнится.
# - Строка 104: `        final_df = final_df.drop(columns=[forbidden_col])` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 106: `print(f'Собрано строк: {len(final_df):,}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 107: `print(f'Атрибутов в финале: {len(final_df.columns)}')` — Выводит диагностический результат для контроля корректности шага.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
base_df = sa_df.copy()
print(f'Строк на старте (SA): {len(base_df):,}')

if not cdi_map_df.empty and not base_df.empty:
    before_rows = len(base_df)
    base_df = base_df.merge(cdi_map_df[['inn', 'cdi_id', 'ssp_ocrm']], on='inn', how='left')
    print(f'После merge INN->CDI: {before_rows:,} -> {len(base_df):,}')
else:
    base_df['cdi_id'] = None
    base_df['ssp_ocrm'] = None

if not cft_map_df.empty and not base_df.empty:
    before_rows = len(base_df)
    base_df = base_df.merge(cft_map_df[['cdi_id', 'cft_id']], on='cdi_id', how='left')
    print(f'После merge CDI->CFT: {before_rows:,} -> {len(base_df):,}')
else:
    base_df['cft_id'] = None

if not r2_df.empty and not base_df.empty:
    before_rows = len(base_df)
    base_df = base_df.merge(r2_df, on='cft_id', how='left')
    print(f'После merge CFT->R2: {before_rows:,} -> {len(base_df):,}')
else:
    for col in ['r2_id', 'commission_monthly', 'ogrn', 'filial_rf', 'vsp_name', 'vsp_code', 'tariff_name']:
        base_df[col] = None

if not cmp_df.empty and not base_df.empty:
    before_rows = len(base_df)
    base_df = base_df.merge(cmp_df[['n_cmp_client', 'retl_cnt', 'term_cnt', 'amortization']], on='n_cmp_client', how='left')
    print(f'После merge company metrics: {before_rows:,} -> {len(base_df):,}')
else:
    for col in ['retl_cnt', 'term_cnt', 'amortization']:
        base_df[col] = None

if not trx_df.empty and not base_df.empty:
    before_rows = len(base_df)
    base_df = base_df.merge(trx_df[['n_agr', 'trx_cnt', 'trx_sum', 'commission_from_ops', 'int_component']], on='n_agr', how='left')
    print(f'После merge TRX metrics: {before_rows:,} -> {len(base_df):,}')
else:
    for col in ['trx_cnt', 'trx_sum', 'commission_from_ops', 'int_component']:
        base_df[col] = None

if 'agr_id' not in base_df.columns:
    base_df['agr_id'] = None
if 'r2_id' not in base_df.columns:
    base_df['r2_id'] = None

agr_id_before_fill = base_df['agr_id'].notna() & (base_df['agr_id'].astype(str).str.strip() != '')
base_df['agr_id_source'] = 'sa'
fallback_mask = (~agr_id_before_fill) & base_df['r2_id'].notna() & (base_df['r2_id'].astype(str).str.strip() != '')
base_df.loc[fallback_mask, 'agr_id'] = base_df.loc[fallback_mask, 'r2_id']
base_df.loc[fallback_mask, 'agr_id_source'] = 'r2_fallback'

agr_id_after_fill = base_df['agr_id'].notna() & (base_df['agr_id'].astype(str).str.strip() != '')
agr_fill_before_pct = round(100.0 * agr_id_before_fill.mean(), 2) if len(base_df) else 0.0
agr_fill_after_pct = round(100.0 * agr_id_after_fill.mean(), 2) if len(base_df) else 0.0
agr_fallback_rows = int(fallback_mask.sum())
print(f'Заполняемость agr_id до fallback: {agr_fill_before_pct}%')
print(f'Заполняемость agr_id после fallback: {agr_fill_after_pct}%')
print(f'Строк, где применен fallback agr_id <- r2_id: {agr_fallback_rows:,}')

commission_from_ops_num = pd.to_numeric(base_df.get('commission_from_ops'), errors='coerce').fillna(0)
commission_monthly_num = pd.to_numeric(base_df.get('commission_monthly'), errors='coerce').fillna(0)
int_component_num = pd.to_numeric(base_df.get('int_component'), errors='coerce').fillna(0)
amortization_num = pd.to_numeric(base_df.get('amortization'), errors='coerce').fillna(0)

base_df['commission_total'] = commission_from_ops_num + commission_monthly_num

term_cnt_num = pd.to_numeric(base_df.get('term_cnt'), errors='coerce')
retl_cnt_num = pd.to_numeric(base_df.get('retl_cnt'), errors='coerce')
aur_units = term_cnt_num.where(term_cnt_num.notna() & (term_cnt_num > 0), retl_cnt_num)
base_df['aur'] = aur_units * 1926

aur_num = pd.to_numeric(base_df.get('aur'), errors='coerce').fillna(0)
base_df['chod'] = base_df['commission_total'] - int_component_num
base_df['fin_result'] = base_df['chod'] - aur_num - amortization_num
base_df['report_month'] = report_month_label

mvp_columns = [
    'report_month', 'inn', 'company_name',
    'agr_id', 'n_agr', 'contract_number', 'd_valid_from', 'd_valid_to',
    'cdi_id', 'ssp_ocrm', 'ogrn', 'filial_rf', 'vsp_name', 'vsp_code', 'tariff_name',
    'retl_cnt', 'term_cnt', 'trx_cnt', 'trx_sum',
    'commission_from_ops', 'commission_monthly', 'int_component', 'commission_total',
    'aur', 'amortization', 'chod', 'fin_result'
]

for col in mvp_columns:
    if col not in base_df.columns:
        base_df[col] = None

for col in ['trx_sum', 'commission_from_ops', 'commission_monthly', 'int_component', 'commission_total', 'aur', 'amortization', 'chod', 'fin_result']:
    if col in base_df.columns:
        base_df[col] = base_df[col].map(to_decimal_or_none)

for col in ['retl_cnt', 'term_cnt', 'trx_cnt']:
    if col in base_df.columns:
        base_df[col] = pd.to_numeric(base_df[col], errors='coerce').astype('Int64')

final_df = base_df[mvp_columns].copy()

for forbidden_col in ['n_cmp_client', 'key_tier', 'dq_block_reason', 'r2_id', 'agr_id_source']:
    if forbidden_col in final_df.columns:
        final_df = final_df.drop(columns=[forbidden_col])

print(f'Собрано строк: {len(final_df):,}')
print(f'Атрибутов в финале: {len(final_df.columns)}')

# %% [markdown]
# ## 5) Проверка заполняемости полей витрины
#
# Контроль заполненности каждого атрибута финальной витрины для поиска проблемных мест.

# %% [markdown]
# ### Подробный разбор кода (ячейка 14)
#
# - Строка 1: `row_cnt = len(final_df)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 3: `field_fill_stats = []` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 4: `for col in final_df.columns:` — Цикл по набору элементов (колонки, строки, список значений и т.п.).
# - Строка 5: `    non_null_cnt = int(final_df[col].notna().sum())` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 6: `    null_cnt = int(row_cnt - non_null_cnt)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 7: `    fill_rate_pct = round((non_null_cnt / row_cnt) * 100, 2) if row_cnt else 0.0` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 8: `    field_fill_stats.append({` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 9: `        'field_name': col,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 10: `        'non_null_cnt': non_null_cnt,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 11: `        'null_cnt': null_cnt,` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 12: `        'fill_rate_pct': fill_rate_pct` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 13: `    })` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 15: `fill_stats_df = pd.DataFrame(field_fill_stats).sort_values(['fill_rate_pct', 'field_name'], ascending=[True, True]).reset_index(drop=True)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 17: `print(f'Строк в финальной витрине: {row_cnt:,}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 18: `fill_stats_df` — Выполняет очередной технический шаг обработки в рамках pipeline.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
row_cnt = len(final_df)

field_fill_stats = []
for col in final_df.columns:
    non_null_cnt = int(final_df[col].notna().sum())
    null_cnt = int(row_cnt - non_null_cnt)
    fill_rate_pct = round((non_null_cnt / row_cnt) * 100, 2) if row_cnt else 0.0
    field_fill_stats.append({
        'field_name': col,
        'non_null_cnt': non_null_cnt,
        'null_cnt': null_cnt,
        'fill_rate_pct': fill_rate_pct
    })

fill_stats_df = pd.DataFrame(field_fill_stats).sort_values(['fill_rate_pct', 'field_name'], ascending=[True, True]).reset_index(drop=True)

print(f'Строк в финальной витрине: {row_cnt:,}')
fill_stats_df

# %% [markdown]
# ## 6) Предпросмотр финальной витрины
#
# Показываем первые 5 строк перед выгрузкой.

# %% [markdown]
# ### Подробный разбор кода (ячейка 15)
#
# - Строка 1: `final_df.head(5)` — Выполняет очередной технический шаг обработки в рамках pipeline.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
final_df.head(5)

# %% [markdown]
# ## 7) Выгрузка в CSV
#
# Сохраняем результат в указанный путь.

# %% [markdown]
# ### Подробный разбор кода (ячейка 16)
#
# - Строка 1: `output_path = Path(output_csv_path)` — Сохраняет результат текущего шага в переменную для следующих операций.
# - Строка 2: `output_path.parent.mkdir(parents=True, exist_ok=True)` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 4: `final_df.to_csv(output_path, index=False, encoding='utf-8-sig')` — Выполняет очередной технический шаг обработки в рамках pipeline.
# - Строка 6: `print(f'CSV сохранен: {output_path.resolve()}')` — Выводит диагностический результат для контроля корректности шага.
# - Строка 7: `print(f'Строк: {len(final_df):,}')` — Выводит диагностический результат для контроля корректности шага.

# %%
# Код ячейки оставлен без изменения (рабочая логика)
output_path = Path(output_csv_path)
output_path.parent.mkdir(parents=True, exist_ok=True)

final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

print(f'CSV сохранен: {output_path.resolve()}')
print(f'Строк: {len(final_df):,}')
