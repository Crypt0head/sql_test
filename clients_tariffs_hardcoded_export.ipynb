# %% [markdown]
# # Хардкод: клиенты, договоры, ОГРН и тарифы
#
# Тетрадка формирует Excel для коллеги без SQL и без подключений к источникам.
# Данные зафиксированы вручную по подтвержденным соответствиям из фото.

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 220)

# %%
hardcoded_rows = [
    {'Клиент': 'БИКМЕТОВА САЗИДА АСХАТОВНА (ИП)', 'ОГРН': '325028000279052', 'Номер договора': 'ЭД266219/00028', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'ЛАРИН АЛЕКСАНДР НИКОЛАЕВИЧ (ИП ГКФХ)', 'ОГРН': '304025512800036', 'Номер договора': 'ЭД266213/00034', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'БАГАУТДИНОВ РАБИЛ ЗИЯФОВИЧ (ИП)', 'ОГРН': '326028000007223', 'Номер договора': 'ЭД266206/00045', 'Тариф': 'Эквайринг. Тариф "МЕНЮ ВОЗМОЖНОСТЕЙ" опция "Гибкий чек"'},
    {'Клиент': 'ЛИ ЖЭНЬШУНЬ (ИП)', 'ОГРН': '320028000097857', 'Номер договора': 'ЭД266235/00033', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'ООО "НЬЮРИС"', 'ОГРН': '1149102120441', 'Номер договора': 'ЭД_300', 'Тариф': 'Эквайринг. Индивидуальный тариф для договора ЭД_300'},
    {'Клиент': 'ФРАНТЕНКО ВИКТОРИЯ КОНСТАНТИНОВНА (ИП)', 'ОГРН': '323385000127952', 'Номер договора': 'ЭД256615/00027', 'Тариф': 'Эквайринг. Тариф "МЕНЮ ВОЗМОЖНОСТЕЙ" опция "Гибкий чек"'},
    {'Клиент': 'ООО "КРОСС+"', 'ОГРН': '1053811141230', 'Номер договора': 'ЭД_000098', 'Тариф': 'Мерчанты. Индивидуальный ТП для договора'},
    {'Клиент': 'ООО "САНИВА"', 'ОГРН': '1114613000490', 'Номер договора': 'ЭД263226/00020', 'Тариф': 'Эквайринг. Тариф "Индивидуальный"'},
    {'Клиент': 'ООО "СВТ"', 'ОГРН': '1095321000070', 'Номер договора': 'ЭД250800/00022', 'Тариф': 'Эквайринг. Тариф "МЕНЮ ВОЗМОЖНОСТЕЙ" опция "Гибкий чек"'},
    {'Клиент': 'ООО "КУПЕЦ"', 'ОГРН': '1105543001520', 'Номер договора': 'ЭД262553/00005', 'Тариф': 'Эквайринг. Тариф "МЕНЮ ВОЗМОЖНОСТЕЙ" опция "Гибкий чек"'},
    {'Клиент': 'КИЯН МАРИНА НИКОЛАЕВНА (ИП)', 'ОГРН': '326547600049591', 'Номер договора': 'ЭД262504/00044', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'ЛАНГ ЭДУАРД ЭДУАРДОВИЧ (ИП)', 'ОГРН': '322547600045721', 'Номер договора': 'ЭД262500/00043', 'Тариф': 'Эквайринг. Тариф "МЕНЮ ВОЗМОЖНОСТЕЙ" опция "Гибкий чек"'},
    {'Клиент': 'МУШЕНКО МАКСИМ АНАТОЛЬЕВИЧ (ИП)', 'ОГРН': '323547600047523', 'Номер договора': 'ЭД252500/00007', 'Тариф': 'Эквайринг. Тариф "МЕНЮ ВОЗМОЖНОСТЕЙ" опция "Гибкий чек"'},
    {'Клиент': 'АЛЛАЗОВА СУДАБА ИЛЯС КЫЗЫ (ИП)', 'ОГРН': '324246800091492', 'Номер договора': 'ЭД252500/00010', 'Тариф': 'Эквайринг. Тариф "МЕНЮ ВОЗМОЖНОСТЕЙ" опция "Гибкий чек"'},
    {'Клиент': 'ООО "ПРИВОЛЬНОЕ"', 'ОГРН': '1115658002020', 'Номер договора': 'ЭД260519/00077', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'МИНАЗКИРОВ КИРИЛЛ ЭДУАРДОВИЧ (ИП)', 'ОГРН': '325565800030598', 'Номер договора': 'ЭД250507/00108', 'Тариф': 'Эквайринг. Тариф "МЕНЮ ВОЗМОЖНОСТЕЙ" опция "Гибкий чек"'},
    {'Клиент': 'ООО "САНФОРТ-СЕРВИС"', 'ОГРН': '1025801369076', 'Номер договора': 'ЭД261500/00015', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'ТУГАЕВА ЮЛИЯ ВАЛЕРЬЕВНА (ИП)', 'ОГРН': '307583611500025', 'Номер договора': 'ЭД261500/00016', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'ШАБАЛИН ДМИТРИЙ НИКОЛАЕВИЧ (ИП ГКФХ)', 'ОГРН': '325595800099432', 'Номер договора': 'ЭД267605/00036', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'ООО "ЛИОНА"', 'ОГРН': '1225900023315', 'Номер договора': 'ЭД267605/00043', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'СЕЛЕЗНЕВА МАРГАРИТА ФАНИЛЬЕВНА (ИП)', 'ОГРН': '326965800023753', 'Номер договора': 'ЭД267309/00035', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'ПОПОВ АЛЕКСАНДР ВЛАДИМИРОВИЧ (ИП ГКФХ)', 'ОГРН': '319665800113563', 'Номер договора': 'ЭД267300/00047', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'НЕСТЕРОВА МАРИНА АНДРЕЕВНА (ИП)', 'ОГРН': '322665800105220', 'Номер договора': 'ЭД267306/00038', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'ЗИННАТУЛЛИНА ГУЗАЛЬ ВАКЫФОВНА (ИП ГКФХ)', 'ОГРН': '312167520800136', 'Номер договора': 'ЭД266700/00045', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'ГИЗЕТДИНОВ ИЛЬНУР АЛЬБЕРТОВИЧ (ИП)', 'ОГРН': '326169000072080', 'Номер договора': 'ЭД266721/00037', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'СИБГАТУЛЛИНА АЛИЯ ИРЕКОВНА (ИП)', 'ОГРН': '320169000141554', 'Номер договора': 'ЭД256705/00004', 'Тариф': 'Эквайринг. Тариф "МЕНЮ ВОЗМОЖНОСТЕЙ" опция "Гибкий чек"'},
    {'Клиент': 'ООО "АВТОДЕТАЛИ"', 'ОГРН': '1131651000250', 'Номер договора': 'ЭД266716/00040', 'Тариф': 'Эквайринг. Тариф "Стандарт"'},
    {'Клиент': 'АШИМЖОНОВ РАСУЛЖОН АРАБЖОНОВИЧ (ИП)', 'ОГРН': '313169000166854', 'Номер договора': 'ЭД256705/00005', 'Тариф': ''},
]

clients_tariff_df = pd.DataFrame(hardcoded_rows)

print(f'Строк в итоговой таблице: {len(clients_tariff_df):,}')
print(f'Пустых тарифов: {clients_tariff_df["Тариф"].eq("").sum():,}')
display(clients_tariff_df)

# %%
output_excel_path = 'clients_tariffs_hardcoded.xlsx'

clients_tariff_df.to_excel(output_excel_path, index=False)

print(f'Excel-файл сохранен: {output_excel_path}')
print('Колонки выгрузки:', ', '.join(clients_tariff_df.columns.tolist()))
